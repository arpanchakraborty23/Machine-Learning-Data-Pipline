# %%
import pandas as pd
import sys
import yaml
import os
from src.utils import read_yaml

# Load Params from yaml file
params = read_yaml('params.yaml')['preprocess']

# %%
os.makedirs(os.path.dirname(params['artifacts']), exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.makedirs(os.path.dirname(params['artifacts']), exist_ok=True)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: ''

# %%
os.makedirs(os.path.join(params['output']),exist_ok=True)
